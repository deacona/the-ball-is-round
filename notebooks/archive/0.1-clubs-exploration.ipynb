# %% [markdown]
# # First look at clubs dataset

# %%
import sys
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.expand_frame_repr', False)
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import numpy as np
import warnings
warnings.filterwarnings('ignore')
sys.path.insert(0, r'..\src')
import config
import utilities
import clubs

# %%
fulldata = utilities.get_master("fulldata")
fulldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384706 entries, 0 to 384705
# Data columns (total 92 columns):
# Unnamed: 0               384706 non-null int64
# Season                   384706 non-null object
# Div                      384706 non-null object
# Country                  384706 non-null object
# Tier                     384706 non-null int64
# Date                     384706 non-null object
# Team                     303498 non-null object
# TeamOpp                  303498 non-null object
# Goals                    384702 non-null float64
# GoalsOpp                 384702 non-null float64
# Goals1stHalf             342505 non-null float64
# Goals1stHalfOpp          342505 non-null float64
# Attendance               11680 non-null float64
# Referee                  122554 non-null object
# Shots                    174963 non-null float64
# ShotsOpp                 174963 non-null float64
# ShotsOnTarget            173127 non-null float64
# ShotsOnTargetOpp         173127 non-null float64
# ShotsHitWoodwork         11352 non-null float64
# ShotsHitWoodworkOpp      11352 non-null float64
# Corners                  174216 non-null float64
# CornersOpp               174216 non-null float64
# Fouls                    170978 non-null float64
# FoulsOpp                 170978 non-null float64
# Offsides                 11354 non-null float64
# OffsidesOpp              11354 non-null float64
# YellowCards              178349 non-null float64
# YellowCardsOpp           178349 non-null float64
# RedCards                 178348 non-null float64
# RedCardsOpp              178348 non-null float64
# BookingPoints            11696 non-null float64
# BookingPointsOpp         11696 non-null float64
# HomeAway                 384706 non-null object
# GoalsDiff                384702 non-null float64
# TotalGoals               384702 non-null float64
# Goals1stHalfDiff         342504 non-null float64
# TotalGoals1stHalf        342504 non-null float64
# ShotsDiff                174960 non-null float64
# TotalShots               174960 non-null float64
# ShotsOnTargetDiff        173124 non-null float64
# TotalShotsOnTarget       173124 non-null float64
# ShotsHitWoodworkDiff     11352 non-null float64
# TotalShotsHitWoodwork    11352 non-null float64
# CornersDiff              174216 non-null float64
# TotalCorners             174216 non-null float64
# FoulsDiff                170978 non-null float64
# TotalFouls               170978 non-null float64
# OffsidesDiff             11354 non-null float64
# TotalOffsides            11354 non-null float64
# YellowCardsDiff          178348 non-null float64
# TotalYellowCards         178348 non-null float64
# RedCardsDiff             178346 non-null float64
# TotalRedCards            178346 non-null float64
# BookingPointsDiff        11696 non-null float64
# TotalBookingPoints       11696 non-null float64
# Saves                    173127 non-null float64
# SavesOpp                 173127 non-null float64
# SavesDiff                173124 non-null float64
# Goals2ndHalf             342505 non-null float64
# Goals2ndHalfOpp          342505 non-null float64
# Goals2ndHalfDiff         342504 non-null float64
# Result                   384706 non-null object
# Points                   384706 non-null int64
# PointsOpp                384706 non-null int64
# Win                      384706 non-null int64
# WinDraw                  384706 non-null int64
# Draw                     384706 non-null int64
# DrawLoss                 384706 non-null int64
# Loss                     384706 non-null int64
# WinShare                 384706 non-null float64
# CleanSheet               384706 non-null int64
# CleanSheetOpp            384706 non-null int64
# GameWeek                 384706 non-null int64
# City                     146068 non-null object
# Stadium                  156871 non-null object
# Capacity                 156871 non-null float64
# Latitude                 156871 non-null float64
# Longitude                156871 non-null float64
# Easting                  57571 non-null float64
# Northing                 57571 non-null float64
# Grid Reference           57571 non-null object
# CityOpp                  146068 non-null object
# StadiumOpp               156871 non-null object
# CapacityOpp              156871 non-null float64
# LatitudeOpp              156871 non-null float64
# LongitudeOpp             156871 non-null float64
# EastingOpp               57571 non-null float64
# NorthingOpp              57571 non-null float64
# Grid ReferenceOpp        57571 non-null object
# EuclideanDistance        126792 non-null float64
# Manager                  34582 non-null object
# ManagerOpp               34582 non-null object
# dtypes: float64(63), int64(12), object(17)
# memory usage: 270.0+ MB

# %%
fulldata.HomeAway.value_counts()
# Out:
# Home    192353
# Away    192353
# Name: HomeAway, dtype: int64

# %% [markdown]
# Note this dataset double counts matches because each match will occur as "Home" and "Away" entries.

# %%
pd.crosstab(fulldata.Season, fulldata.Country, margins=True)
# Out:
# Country    Belgium  England  France  Germany  Greece  Holland  Italy  Portugal  Scotland  Spain  Turkey     All
# Season
# 1993-1994        0     3004     760     1372       0      612    612         0         0    760       0    7120
# 1994-1995        0     3118     760     1224     612      612    612       612       720    760     612    9642
# 1995-1996      612     2942     760     1224     612      612    612       612       720    924     612   10242
# 1996-1997      612     3022    1684     1224     612      612    612       612       720   1684     612   12006
# 1997-1998      612     3200    1536     1224     612      612   1372       612      1440   1684     612   13516
# 1998-1999      612     2944    1372     1224     612      612   1372       612      1440   1684     612   13096
# 1999-2000      612     3028    1372     1224     612      612   1372       612      1440   1684     612   13180
# 2000-2001      612     2990    1372     1224     480      612   1372       612      1536   1684     612   13106
# 2001-2002      612     3196    1372     1224     364      612   1372       612      1536   1684     612   13196
# 2002-2003      544     3432    1520     1224     480      612   1372       612      1536   1684     612   13628
# 2003-2004      612     3800    1520     1224     480      612   1716       612      1536   1684     612   14408
# 2004-2005      612     3702    1520     1224     480      612   1684       612      1536   1684     612   14278
# 2005-2006      612     4976    1520     1224     480      612   1684       612      1536   1684     612   15552
# 2006-2007      612     5246    1520     1224     480      612   1684       480      1536   1684     612   15690
# 2007-2008      612     5532    1520     1224     480      612   1684       480      1536   1684     612   15976
# 2008-2009      612     5702    1520     1224     480      612   1684       480      1536   1684     612   16146
# 2009-2010      420     5886    1520     1224     480      612   1684       480      1536   1684     544   16070
# 2010-2011      480     6642    1520     1224     480      612   1684       480      1536   1684     612   16954
# 2011-2012      480     7092    1520     1224     480      612   1684       480      1536   1684     612   17404
# 2012-2013      480     7060    1520     1224     480      612   1684       480      1536   1684     612   17372
# 2013-2014      480     7652    1520     1224     612      612   1684       480      1536   1684     612   18096
# 2014-2015      480     5328    1520     1224     612      612   1684       612      1536   1684     612   15904
# 2015-2016      480     7912    1520     1224     480      612   1684       612      1536   1684     612   18356
# 2016-2017      480     9282    1520     1224     480      612   1684       612      1536   1684     612   19726
# 2017-2018      480     9766    1520     1224     480      612   1684       612      1536   1684     612   20210
# 2018-2019      416     7130     998      790     336      396    908       396      1024   1042     396   13832
# All          13176   133584   36306    31538   12796    15696  36880     14028     35152  40534   15016  384706

# %% [markdown]
# So we clearly have some incomplete data - particularly for early 2000s.
#
# Also the English data has far too volatile count. I suspect my pre-processing is re-arranging the data in unexpected days.
#
# Let's make a note to investigate those issues but carry on with our initial analysis...

# %%
plt.figure();
hist_metrics = ["TotalGoals", "TotalShots", "TotalYellowCards", "TotalRedCards", "TotalCorners"]
for item in hist_metrics:
#     print fulldata[item].max()+1
    fulldata.hist(column=[item], bins=range(int(fulldata[item].max()+1)))

# %%
fulldata[fulldata.HomeAway=="Home"].Result.value_counts(normalize=True)
# Out:
# Win     0.454482
# Loss    0.275286
# Draw    0.270232
# Name: Result, dtype: float64

# %% [markdown]
# ## Spot checks on Ajax

# %% [markdown]
# Let's take Ajax as an example and check that their season performances do match those here https://en.wikipedia.org/wiki/List_of_AFC_Ajax_seasons

# %%
group_key = "Season"
base_filters = {
        "Team": ["Ajax"]
        }
output_metrics = [
        "NumberOfMatches",
        "Win", "Draw", "Loss",
        "Goals", "GoalsOpp", 
        ]
ajax = clubs.get_summary(group_key, df=None, base_filters=base_filters, 
                       output_metrics=output_metrics, agg_method=sum)
ajax
# Out:
#            NumberOfMatches  Win  Draw  Loss  Goals  GoalsOpp
# 1997-1998               34   29     2     3  112.0      22.0
# 2000-2001               34   18     7     9   85.0      43.0
# 2001-2002               34   22     7     5   73.0      34.0
# 2002-2003               34   26     5     3   96.0      32.0
# 2003-2004               34   25     5     4   79.0      31.0
# 2004-2005               34   24     5     5   74.0      33.0
# 2005-2006               34   18     6    10   66.0      41.0
# 2006-2007               34   23     6     5   84.0      35.0
# 2007-2008               34   20     9     5   94.0      45.0
# 2008-2009               34   21     5     8   74.0      41.0
# 2009-2010               34   27     4     3  106.0      20.0
# 2010-2011               33   21     7     5   69.0      29.0
# 2011-2012               34   23     7     4   93.0      36.0
# 2013-2014               34   20    11     3   69.0      28.0
# 2014-2015               34   21     8     5   69.0      29.0
# 2015-2016               34   25     7     2   81.0      21.0
# 2016-2017               34   25     6     3   79.0      23.0
# 2017-2018               34   25     4     5   89.0      33.0
# 2018-2019               22   17     2     3   77.0      19.0

# %% [markdown]
# So (pretty much it all matches up. Missing seasons are 93/4, 94/5, 95/6, 96/7, 98/9, 99/2000. Also curiously we're missing one game from 2010-2011 - a 3-1 win?

# %% [markdown]
# ## Spot checks on Frankfurt

# %% [markdown]
# Let's take Eintracht Frankfurt as a second example and check them out versus https://en.wikipedia.org/wiki/List_of_Eintracht_Frankfurt_seasons

# %%
group_key = "Season"
base_filters = {
        "Team": ["Ein Frankfurt"]
        }
output_metrics = [
        "NumberOfMatches",
        "Win", "Draw", "Loss",
        "Goals", "GoalsOpp", 
        ]
frankfurt = clubs.get_summary(group_key, df=fulldata.copy(), base_filters=base_filters, 
                       output_metrics=output_metrics, agg_method=sum)
frankfurt
# Out:
#            NumberOfMatches  Win  Draw  Loss  Goals  GoalsOpp
# 1997-1998               34   17    13     4   50.0      32.0
# 1998-1999               34    9    10    15   44.0      54.0
# 2000-2001               34   10     5    19   41.0      68.0
# 2001-2002               34   14    12     8   52.0      44.0
# 2002-2003               34   17    11     6   59.0      33.0
# 2003-2004               34    9     5    20   36.0      53.0
# 2004-2005               34   19     4    11   65.0      39.0
# 2005-2006               34    9     9    16   42.0      51.0
# 2006-2007               34    9    13    12   46.0      58.0
# 2007-2008               34   12    10    12   43.0      50.0
# 2008-2009               34    8     9    17   39.0      60.0
# 2009-2010               34   12    10    12   47.0      54.0
# 2010-2011               34    9     7    18   31.0      49.0
# 2011-2012               34   20     8     6   76.0      33.0
# 2012-2013               34   14     9    11   49.0      46.0
# 2013-2014               34    9     9    16   40.0      57.0
# 2014-2015               34   11    10    13   56.0      62.0
# 2015-2016               34    9     9    16   34.0      52.0
# 2016-2017               34   11     9    14   36.0      43.0
# 2017-2018               34   14     7    13   45.0      45.0
# 2018-2019               22    9     7     6   41.0      28.0

# %% [markdown]
# Again, it's mostly spot-on. This time missing years are 93/4, 94/5, 95/6, 96/7, 99/2000, and in 2010-2011 we have 3 extra goals conceded appearing!

# %% [markdown]
# ## Mapping the data

# %%
import seaborn
seaborn.set(style='ticks')

mapdata=fulldata.dropna(subset=['Latitude', 'Longitude'])
# mapdata.info()
fg = seaborn.FacetGrid(data=mapdata, hue='Country', aspect=1.)
fg.map(plt.scatter, 'Longitude', 'Latitude').add_legend()

# %%
fulldata[fulldata.City=="London "].groupby(['Stadium'])[["Latitude","Longitude"]].max()
# Out:
#                     Latitude  Longitude
# Stadium
# Boleyn Ground      51.531944   0.039444
# Craven Cottage     51.475000  -0.221667
# Emirates Stadium   51.555000  -0.108611
# Griffin Park       51.488183  -0.302639
# Loftus Road        51.509167  -0.232222
# Selhurst Park      51.398333  -0.085556
# Stamford Bridge    51.481667  -0.191111
# The Den            51.485953  -0.050950
# White Hart Lane    51.603333  -0.065833

# %%
# Extract the data we're interested in
lat = fulldata.groupby(['Stadium'])[["Latitude"]].max().values
lon = fulldata.groupby(['Stadium'])[["Longitude"]].max().values

# print lat, lon

# %%
# 1. Draw the map background
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc', resolution='h', 
            lat_0=46., lon_0=-3.,
            width=3E6, height=3E6)
m.shadedrelief()
m.drawcoastlines(color='gray')
m.drawcountries(color='black')

# 2. scatter stadium data
m.scatter(lon, lat, latlon=True,
          color='r', s=40,
          alpha=0.5)
